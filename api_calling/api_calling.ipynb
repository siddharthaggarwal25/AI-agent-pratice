# %%
from dotenv import load_dotenv
import os
from langchain_google_genai import ChatGoogleGenerativeAI

load_dotenv()
# Out:
# True

# %%
print( os.getenv("GOOGLE_API_KEY") )
# Out:
# AIzaSyAV9T3xixEoZ_UxE3nRpAaU9pb_G7JNRB0

# %%
llm = ChatGoogleGenerativeAI(model="gemma-4-31b-it")
response = llm.invoke("What is the capital of France?")
print(response)
# Out:
# content=[{'type': 'thinking', 'thinking': 'The user is asking for the capital city of France.\nFrance.\nCapital.\nParis.'}, {'type': 'text', 'text': 'The capital of France is Paris.'}] additional_kwargs={} response_metadata={'finish_reason': 'STOP', 'model_name': 'gemma-4-31b-it', 'safety_ratings': [], 'model_provider': 'google_genai'} id='lc_run--019e64c9-df4f-70d0-b824-a9dd63c1eff7-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 8, 'output_tokens': 27, 'total_tokens': 35, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 20}}

# %%
from langchain.agents import create_agent
from langgraph.checkpoint.memory import InMemorySaver

def get_weather_and_temp_today(city: str) -> str:
    """Get weather for a given city."""
    return f"It's always sunny in {city} and 36degree celcius today!"

agent = create_agent(
    model="google_genai:gemini-2.5-flash-lite",
    tools=[get_weather_and_temp_today],
    system_prompt="You are a helpful assistant",
    checkpointer=InMemorySaver()
)

result = agent.invoke(
    {"messages": [{"role": "user", "content": "What's the weather in San Francisco?"}]},
    config={"configurable": {"thread_id": "1"}},
)
print(result["messages"][-1].content)

result = agent.invoke(
    {"messages": [{"role": "user", "content": "What's the temp there?"}]},
    config={"configurable": {"thread_id": "1"}},
)
print(result["messages"][-1].content)
# Out:
# The weather in San Francisco is sunny and 36 degrees Celsius.
# 36 degrees Celsius.

# %%
# Out:
# [{'type': 'text', 'text': "I'm sorry, I need a city name to get the temperature. What city are you referring to?"}]
